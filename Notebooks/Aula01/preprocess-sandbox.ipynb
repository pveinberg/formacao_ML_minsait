# %% [markdown]
# ## Preprocess sandbox

# %%
# %load_ext autoreload
# %autoreload 2

from preprocess import Preprocess

# %%
base = "./../../Datasets/kc_house_data.csv"
try:
    pp = Preprocess(base)
    pp.clean(["id"])
    display(pp.data.head())
except Exception as e:
    print(e)
# Out:
# Deleting 1 col(s): ['id']
# The dataset have 0 duplicated row(s)
# Nothing to do.
#               date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  20141013T000000  221900.0       3.0       1.00         1180      5650
# 1  20141209T000000  538000.0       3.0       2.25         2570      7242
# 2  20150225T000000  180000.0       2.0       1.00          770     10000
# 3  20141209T000000  604000.0       4.0       3.00         1960      5000
# 4  20150218T000000  510000.0       3.0       2.00         1680      8080
#
#    floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0     1.0           0     0          3      7        1180              0
# 1     2.0           0     0          3      7        2170            400
# 2     1.0           0     0          3      6         770              0
# 3     1.0           0     0          5      7        1050            910
# 4     1.0           0     0          3      8        1680              0
#
# ...

# %%
data = pp.data

data.head()
# Out:
#               date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  20141013T000000  221900.0       3.0       1.00         1180      5650
# 1  20141209T000000  538000.0       3.0       2.25         2570      7242
# 2  20150225T000000  180000.0       2.0       1.00          770     10000
# 3  20141209T000000  604000.0       4.0       3.00         1960      5000
# 4  20150218T000000  510000.0       3.0       2.00         1680      8080
#
#    floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0     1.0           0     0          3      7        1180              0
# 1     2.0           0     0          3      7        2170            400
# 2     1.0           0     0          3      6         770              0
# 3     1.0           0     0          5      7        1050            910
# 4     1.0           0     0          3      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
temp = list(data.columns)
del temp[1:2]
data[data.duplicated(subset=temp, keep=False)]
# Out:
#                   date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 20354  20140918T000000  367899.0       3.0        2.5         2420      4725
# 20825  20140918T000000  369946.0       3.0        2.5         2420      4725
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 20354     2.0           0     0          3      8        2420              0
# 20825     2.0           0     0          3      8        2420              0
#
#        yr_built  yr_renovated  zipcode     lat     long  sqft_living15  \
# 20354      2014             0    98038  47.371 -122.018           2370
# 20825      2014             0    98038  47.371 -122.018           2370
#
#        sqft_lot15
# 20354        4200
# 20825        4200

# %% [markdown]
# # Importação das bibliotecas

# %%
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import seaborn as sns
from sklearn.metrics import accuracy_score, confusion_matrix,ConfusionMatrixDisplay,roc_curve
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
import mlflow
import mlflow.sklearn

# %%
import warnings
warnings.filterwarnings("ignore")

sns.set_style('darkgrid')

# %% [markdown]
# # Carregando os dados

# %%
Train_Data = pd.read_csv('./../../Datasets/heart.csv')
Train_Data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# Informando dataset no mlflow
mlflow_dataset = mlflow.data.from_pandas(Train_Data, source="datasets_heart.csv", name="Heart Attack Dataset")

# %% [markdown]
# ## Descrição das colunas

# %% [markdown]
# 1. __Age__ is the age of candidate.
# 2. __Sex__ has numeric values. 1 denotes male and 0 denotes female.
# 3. __Chest Pain__ pain has values between 0-3. The types of angina that are described in the research paper. The higher the number, the lesser are the odds of heart attack.
# 4. __Resting blood pressure__ is normal pressure with no exercise.
# 5. __Cholesterol__ means the blockage for blood supply in the blood vessels.
# 6. __Fasting Blood Pressure__ is blood sugar taken after a long gap between a meal and the test. Typically, it's taken before any meal in the morning. 1 denotes > 120 mg/dl
# 7. __Rest ECG (electrocardiographic) results__ means ECG values taken while person is on rest which means no exercise and normal functioning of heart is happening. Values 0,1,2.
# 8. __The Maximum Heart Rate achieved__.
# 9. __Exercise induced angina__ is chest pain while exercising or doing any physical activity. 1 denotes presence and 0 denotes absence.
# 10. __Oldpeak__ = ST Depression induced by exercise relative to rest. ST Depression is the difference between value of ECG at rest and after exercise.
# 11. __ST Slope__ is the tangent to the depression value.
# 12. __The number of major blood vessels (0-3) supplying blood to heart blocked__.
# 13. __The Types of thalassemia__.
# 14. __Heart attack prediction__ where 1 denotes Heart attack occured and 0 where it din't take occur.

# %%
Train_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %% [markdown]
# # Checar se as classes estão balanceadas

# %%
Train_Data['target'].value_counts()
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %% [markdown]
# # Checar se existem dados duplicados

# %%
print("Duplicated values: ", Train_Data.duplicated().sum())
duplicate = Train_Data[Train_Data.duplicated()]
duplicate
# Out:
# Duplicated values:  1
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 164   38    1   2       138   175    0        1      173      0      0.0
#
#      slope  ca  thal  target
# 164      2   4     2       1

# %% [markdown]
# ### Remover dados duplicados, deixando apenas a primeira ocorrência

# %%
Train_Data.drop_duplicates(keep='first', inplace=True) 
Train_Data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [302 rows x 14 columns]

# %% [markdown]
# # Checar se existem dados faltantes

# %%
print("Missing values: ", Train_Data.isnull().sum().sum())
# Out:
# Missing values:  0

# %% [markdown]
# # Checar se existem correlações entre os atributos e a saída

# %%
corr = Train_Data.corr()
corr.style.background_gradient(cmap = 'viridis')
# Out:
# <style type="text/css">
# #T_a210b_row0_col0, #T_a210b_row1_col1, #T_a210b_row2_col2, #T_a210b_row3_col3, #T_a210b_row4_col4, #T_a210b_row5_col5, #T_a210b_row6_col6, #T_a210b_row7_col7, #T_a210b_row8_col8, #T_a210b_row9_col9, #T_a210b_row10_col10, #T_a210b_row11_col11, #T_a210b_row12_col12, #T_a210b_row13_col13 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_a210b_row0_col1 {
#   background-color: #46337f;
#   color: #f1f1f1;
# }
# #T_a210b_row0_col2, #T_a210b_row2_col0, #T_a210b_row4_col3, #T_a210b_row11_col4 {
#   background-color: #3d4e8a;
#   color: #f1f1f1;
# }
# #T_a210b_row0_col3, #T_a210b_row11_col12 {
#   background-color: #2c718e;
#   color: #f1f1f1;
# }
# #T_a210b_row0_col4 {
#   background-color: #30698e;
#   color: #f1f1f1;
# }
# #T_a210b_row0_col5, #T_a210b_row7_col1, #T_a210b_row7_col12, #T_a210b_row8_col3 {
#   background-color: #423f85;
#   color: #f1f1f1;
# }
# #T_a210b_row0_col6 {
#   background-color: #470d60;
#   color: #f1f1f1;
# }
# #T_a210b_row0_col7, #T_a210b_row1_col4, #T_a210b_row4_col6, #T_a210b_row6_col5, #T_a210b_row7_col0, #T_a210b_row8_col2, #T_a210b_row8_col13, #T_a210b_row9_col10, #T_a210b_row10_col9, #T_a210b_row13_col1, #T_a210b_row13_col3, #T_a210b_row13_col8, #T_a210b_row13_col11, #T_a210b_row13_col12 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_a210b_row0_col8, #T_a210b_row1_col11, #T_a210b_row5_col0, #T_a210b_row5_col9 {
#   background-color: #2d718e;
#   color: #f1f1f1;
# }
# #T_a210b_row0_col9, #T_a210b_row11_col0, #T_a210b_row12_col9 {
#   background-color: #21908d;
#   color: #f1f1f1;
# }
# #T_a210b_row0_col10 {
#   background-color: #3a548c;
#   color: #f1f1f1;
# }
# #T_a210b_row0_col11 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_a210b_row0_col12, #T_a210b_row3_col12 {
#   background-color: #34608d;
#   color: #f1f1f1;
# }
# #T_a210b_row0_col13, #T_a210b_row2_col11, #T_a210b_row7_col9 {
#   background-color: #463480;
#   color: #f1f1f1;
# }
# #T_a210b_row1_col0, #T_a210b_row8_col4, #T_a210b_row12_col7 {
#   background-color: #3f4889;
#   color: #f1f1f1;
# }
# #T_a210b_row1_col2, #T_a210b_row12_col4 {
#   background-color: #3c508b;
#   color: #f1f1f1;
# }
# #T_a210b_row1_col3, #T_a210b_row1_col6 {
#   background-color: #481c6e;
#   color: #f1f1f1;
# }
# #T_a210b_row1_col5, #T_a210b_row11_col7, #T_a210b_row12_col6 {
#   background-color: #472a7a;
#   color: #f1f1f1;
# }
# #T_a210b_row1_col7, #T_a210b_row3_col7, #T_a210b_row4_col13, #T_a210b_row6_col12, #T_a210b_row13_col6 {
#   background-color: #3b518b;
#   color: #f1f1f1;
# }
# #T_a210b_row1_col8, #T_a210b_row12_col11 {
#   background-color: #29798e;
#   color: #f1f1f1;
# }
# #T_a210b_row1_col9 {
#   background-color: #277f8e;
#   color: #f1f1f1;
# }
# #T_a210b_row1_col10 {
#   background-color: #2f6b8e;
#   color: #f1f1f1;
# }
# #T_a210b_row1_col12, #T_a210b_row9_col12 {
#   background-color: #297b8e;
#   color: #f1f1f1;
# }
# #T_a210b_row1_col13 {
#   background-color: #482677;
#   color: #f1f1f1;
# }
# #T_a210b_row2_col1, #T_a210b_row12_col3 {
#   background-color: #433e85;
#   color: #f1f1f1;
# }
# #T_a210b_row2_col3 {
#   background-color: #443a83;
#   color: #f1f1f1;
# }
# #T_a210b_row2_col4 {
#   background-color: #482576;
#   color: #f1f1f1;
# }
# #T_a210b_row2_col5, #T_a210b_row2_col6, #T_a210b_row7_col6, #T_a210b_row10_col0, #T_a210b_row12_col2 {
#   background-color: #443983;
#   color: #f1f1f1;
# }
# #T_a210b_row2_col7, #T_a210b_row7_col2 {
#   background-color: #218f8d;
#   color: #f1f1f1;
# }
# #T_a210b_row2_col8, #T_a210b_row3_col6 {
#   background-color: #460b5e;
#   color: #f1f1f1;
# }
# #T_a210b_row2_col9 {
#   background-color: #38588c;
#   color: #f1f1f1;
# }
# #T_a210b_row2_col10 {
#   background-color: #26828e;
#   color: #f1f1f1;
# }
# #T_a210b_row2_col12 {
#   background-color: #472f7d;
#   color: #f1f1f1;
# }
# #T_a210b_row2_col13 {
#   background-color: #23a983;
#   color: #f1f1f1;
# }
# #T_a210b_row3_col0 {
#   background-color: #228d8d;
#   color: #f1f1f1;
# }
# #T_a210b_row3_col1, #T_a210b_row9_col2, #T_a210b_row10_col12 {
#   background-color: #433d84;
#   color: #f1f1f1;
# }
# #T_a210b_row3_col2, #T_a210b_row6_col7 {
#   background-color: #33638d;
#   color: #f1f1f1;
# }
# #T_a210b_row3_col4 {
#   background-color: #39568c;
#   color: #f1f1f1;
# }
# #T_a210b_row3_col5 {
#   background-color: #3c4f8a;
#   color: #f1f1f1;
# }
# #T_a210b_row3_col8, #T_a210b_row4_col8, #T_a210b_row5_col2, #T_a210b_row8_col0 {
#   background-color: #2f6c8e;
#   color: #f1f1f1;
# }
# #T_a210b_row3_col9 {
#   background-color: #218e8d;
#   color: #f1f1f1;
# }
# #T_a210b_row3_col10 {
#   background-color: #365c8d;
#   color: #f1f1f1;
# }
# #T_a210b_row3_col11 {
#   background-color: #2e6f8e;
#   color: #f1f1f1;
# }
# #T_a210b_row3_col13 {
#   background-color: #414487;
#   color: #f1f1f1;
# }
# #T_a210b_row4_col0, #T_a210b_row9_col0 {
#   background-color: #27808e;
#   color: #f1f1f1;
# }
# #T_a210b_row4_col1, #T_a210b_row7_col5, #T_a210b_row8_col6 {
#   background-color: #481a6c;
#   color: #f1f1f1;
# }
# #T_a210b_row4_col2 {
#   background-color: #3e4c8a;
#   color: #f1f1f1;
# }
# #T_a210b_row4_col5 {
#   background-color: #482071;
#   color: #f1f1f1;
# }
# #T_a210b_row4_col7, #T_a210b_row5_col7 {
#   background-color: #375a8c;
#   color: #f1f1f1;
# }
# #T_a210b_row4_col9, #T_a210b_row6_col13 {
#   background-color: #2a778e;
#   color: #f1f1f1;
# }
# #T_a210b_row4_col10, #T_a210b_row10_col2 {
#   background-color: #2d708e;
#   color: #f1f1f1;
# }
# #T_a210b_row4_col11 {
#   background-color: #2e6d8e;
#   color: #f1f1f1;
# }
# #T_a210b_row4_col12 {
#   background-color: #31668e;
#   color: #f1f1f1;
# }
# #T_a210b_row5_col1, #T_a210b_row6_col8 {
#   background-color: #3a538b;
#   color: #f1f1f1;
# }
# #T_a210b_row5_col3, #T_a210b_row5_col13 {
#   background-color: #375b8d;
#   color: #f1f1f1;
# }
# #T_a210b_row5_col4, #T_a210b_row6_col1 {
#   background-color: #443b84;
#   color: #f1f1f1;
# }
# #T_a210b_row5_col6, #T_a210b_row11_col6 {
#   background-color: #481668;
#   color: #f1f1f1;
# }
# #T_a210b_row5_col8 {
#   background-color: #32658e;
#   color: #f1f1f1;
# }
# #T_a210b_row5_col10, #T_a210b_row6_col9, #T_a210b_row12_col0 {
#   background-color: #31678e;
#   color: #f1f1f1;
# }
# #T_a210b_row5_col11, #T_a210b_row11_col8 {
#   background-color: #2a768e;
#   color: #f1f1f1;
# }
# #T_a210b_row5_col12, #T_a210b_row6_col11 {
#   background-color: #3d4d8a;
#   color: #f1f1f1;
# }
# #T_a210b_row6_col0, #T_a210b_row8_col10, #T_a210b_row9_col4 {
#   background-color: #404588;
#   color: #f1f1f1;
# }
# #T_a210b_row6_col2, #T_a210b_row11_col1 {
#   background-color: #33628d;
#   color: #f1f1f1;
# }
# #T_a210b_row6_col3 {
#   background-color: #460a5d;
#   color: #f1f1f1;
# }
# #T_a210b_row6_col4, #T_a210b_row7_col8 {
#   background-color: #471063;
#   color: #f1f1f1;
# }
# #T_a210b_row6_col10 {
#   background-color: #277e8e;
#   color: #f1f1f1;
# }
# #T_a210b_row7_col3 {
#   background-color: #481f70;
#   color: #f1f1f1;
# }
# #T_a210b_row7_col4 {
#   background-color: #453781;
#   color: #f1f1f1;
# }
# #T_a210b_row7_col10 {
#   background-color: #25ab82;
#   color: #f1f1f1;
# }
# #T_a210b_row7_col11, #T_a210b_row10_col8 {
#   background-color: #472d7b;
#   color: #f1f1f1;
# }
# #T_a210b_row7_col13 {
#   background-color: #22a785;
#   color: #f1f1f1;
# }
# #T_a210b_row8_col1 {
#   background-color: #31688e;
#   color: #f1f1f1;
# }
# #T_a210b_row8_col5 {
#   background-color: #482475;
#   color: #f1f1f1;
# }
# #T_a210b_row8_col7 {
#   background-color: #450559;
#   color: #f1f1f1;
# }
# #T_a210b_row8_col9 {
#   background-color: #1e9c89;
#   color: #f1f1f1;
# }
# #T_a210b_row8_col11 {
#   background-color: #2c738e;
#   color: #f1f1f1;
# }
# #T_a210b_row8_col12 {
#   background-color: #297a8e;
#   color: #f1f1f1;
# }
# #T_a210b_row9_col1, #T_a210b_row9_col3, #T_a210b_row12_col10 {
#   background-color: #355f8d;
#   color: #f1f1f1;
# }
# #T_a210b_row9_col5, #T_a210b_row9_col6 {
#   background-color: #481d6f;
#   color: #f1f1f1;
# }
# #T_a210b_row9_col7 {
#   background-color: #470e61;
#   color: #f1f1f1;
# }
# #T_a210b_row9_col8 {
#   background-color: #21918c;
#   color: #f1f1f1;
# }
# #T_a210b_row9_col11 {
#   background-color: #24868e;
#   color: #f1f1f1;
# }
# #T_a210b_row9_col13 {
#   background-color: #440256;
#   color: #f1f1f1;
# }
# #T_a210b_row10_col1 {
#   background-color: #424186;
#   color: #f1f1f1;
# }
# #T_a210b_row10_col3, #T_a210b_row10_col5 {
#   background-color: #46085c;
#   color: #f1f1f1;
# }
# #T_a210b_row10_col4 {
#   background-color: #453882;
#   color: #f1f1f1;
# }
# #T_a210b_row10_col6, #T_a210b_row11_col5 {
#   background-color: #404688;
#   color: #f1f1f1;
# }

# %%
X=Train_Data[Train_Data.columns[Train_Data.columns!='target']]

# %%
Y=Train_Data['target']

# %% [markdown]
# ## Dividir treinamento e teste

# %%
train_x, test_x, train_y,test_y=train_test_split(X,Y,random_state=0,test_size=0.2)
print(train_y.shape, test_y.shape)
# Out:
# (241,) (61,)

# %% [markdown]
# # Normalizando os dados

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(train_x)
X_test_scaled = scaler.fit_transform(test_x)

# %% [markdown]
# # Visualizando normalização

# %%
fig, ax = plt.subplots(ncols=3, figsize=(15,5))
sns.histplot(np.concatenate(X.values), \
            ax=ax[0], bins=10, kde=True) \
                .set_title('Original Data')
sns.histplot(np.concatenate(X_train_scaled), \
            ax=ax[1], bins=10, kde=True) \
                .set_title('Train Scaled Data')
sns.histplot(np.concatenate(X_test_scaled), \
            ax=ax[2], bins=10, kde=True) \
                .set_title('Test Scaled Data')
plt.tight_layout
plt.show()

# %% [markdown]
# # Random Forest

# %%
mlflow.set_experiment("Aula_Ensemble_MLFlow")

with mlflow.start_run():
    mlflow.set_tag("mlflow.runName", "RF: " + str(datetime.now()))
    mlflow.log_input(mlflow_dataset)
    
    mlflow.log_param("n_estimators",100)
    mlflow.log_param("random_state",42)
    model_rf = RandomForestClassifier(n_estimators=100, random_state=42)
    model_rf.fit(X_train_scaled, train_y)
    y_pred_rf = model_rf.predict(X_test_scaled)
    
    #modelo
    mlflow.sklearn.log_model(model_rf, "Random Forest")
    acuracia = round(accuracy_score(test_y, y_pred_rf),2)
    print('Acurácia:' + str(acuracia))
    mlflow.log_metric("acuracia",acuracia)
    print(classification_report(test_y, y_pred_rf))

    cm = confusion_matrix(test_y, y_pred_rf)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["bad","good"])
    disp.plot()
    plt.savefig("confusion.png")
    plt.close()

    mlflow.log_artifact("confusion.png")

mlflow.end_run()
# Out:
# Acurácia:0.87
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86        27
#            1       0.91      0.85      0.88        34
#
#     accuracy                           0.87        61
#    macro avg       0.87      0.87      0.87        61
# weighted avg       0.87      0.87      0.87        61

# %% [markdown]
# # XGBoost

# %%
from xgboost import XGBClassifier

# %%
mlflow.set_experiment("Aula_Ensemble_MLFlow")
from datetime import datetime

with mlflow.start_run():
    mlflow.set_tag("mlflow.runName", "XGB: " + str(datetime.now()))
    mlflow.set_tag("mlflow.source.type", "local")
    mlflow.set_tag("mlflow.user", "pveinberg_custom_user")
    mlflow.log_input(mlflow_dataset)

    xgb = XGBClassifier()
    xgb.fit(X_train_scaled, train_y)
    #Predizendo dados 
    y_pred = xgb.predict(X_test_scaled)
    
    #modelo
    mlflow.sklearn.log_model(xgb,"XGBoost")

    #Verificando modelo
    acuracia = round(accuracy_score(test_y, y_pred),2)
    print('Acurácia:' + str(acuracia))
    print(classification_report(test_y, y_pred))

    cm = confusion_matrix(test_y, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["bad","good"])
    disp.plot()
    plt.savefig("confusion.png")
    plt.close()


    mlflow.log_artifact("confusion.png")   
    
mlflow.end_run()
# Out:
# Acurácia:0.82
#               precision    recall  f1-score   support
#
#            0       0.77      0.85      0.81        27
#            1       0.87      0.79      0.83        34
#
#     accuracy                           0.82        61
#    macro avg       0.82      0.82      0.82        61
# weighted avg       0.82      0.82      0.82        61

# %%
feature_names = train_x.columns

# %%
xgb.get_booster().feature_names = list(feature_names.values)

# %%
xgb.get_booster().feature_names
# Out:
# ['age',
#  'sex',
#  'cp',
#  'trestbps',
#  'chol',
#  'fbs',
#  'restecg',
#  'thalach',
#  'exang',
#  'oldpeak',
#  'slope',
#  'ca',
#  'thal']

# %%
from xgboost import plot_importance

# %%
plot_importance(xgb)
plt.show()

# %%
features = train_x.columns
importances = model_rf.feature_importances_
indices = np.argsort(importances)

plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %%
type(mlflow)
# Out:
# module

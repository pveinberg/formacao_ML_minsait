# %% [markdown]
# Exercício - Dataset Diabetes usando MLFlow
# ==========================================

# %%
mlflow models serve -m runs:/7b89537046154c6d90718b44f0464427/Keras_Model  --port=5001 --env-manager local
mlflow models serve -m runs:/7b89537046154c6d90718b44f0464427/"Random_Forest"  --port=5001 --env-manager local

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.cluster import MiniBatchKMeans
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, ConfusionMatrixDisplay

import tensorflow as tf

from keras.layers import Dense, Activation, Dropout, Flatten
from keras.models import Sequential
from keras.callbacks import EarlyStopping

from imblearn.over_sampling import KMeansSMOTE
from xgboost import XGBClassifier, plot_importance

import math 
import sys
import platform

sys.path.insert(1, '../')

from src.plot import plot_heatmap
from src.train import get_all_subsets, results_regression

import warnings
warnings.filterwarnings("ignore")

# %%
sns.set_style('darkgrid')
PLOT_MEDIUM = (10,6)

# %%
data = pd.read_csv('./../../../Datasets/diabetes.csv')

# %%
display(data.shape, data.head())
# Out:
# (768, 9)
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Missing values
data.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# duplicates
data.duplicated().sum()
# Out:
# 0

# %%
data.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
data_correlation = data.corr()
data_correlation.style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T_8c9f4_row0_col0, #T_8c9f4_row1_col1, #T_8c9f4_row2_col2, #T_8c9f4_row3_col3, #T_8c9f4_row4_col4, #T_8c9f4_row5_col5, #T_8c9f4_row6_col6, #T_8c9f4_row7_col7, #T_8c9f4_row8_col8 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_8c9f4_row0_col1 {
#   background-color: #481c6e;
#   color: #f1f1f1;
# }
# #T_8c9f4_row0_col2 {
#   background-color: #482576;
#   color: #f1f1f1;
# }
# #T_8c9f4_row0_col3, #T_8c9f4_row7_col4 {
#   background-color: #460b5e;
#   color: #f1f1f1;
# }
# #T_8c9f4_row0_col4, #T_8c9f4_row0_col5, #T_8c9f4_row0_col6, #T_8c9f4_row2_col8, #T_8c9f4_row3_col0, #T_8c9f4_row3_col1, #T_8c9f4_row3_col7, #T_8c9f4_row6_col2, #T_8c9f4_row7_col3 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_8c9f4_row0_col7 {
#   background-color: #21a685;
#   color: #f1f1f1;
# }
# #T_8c9f4_row0_col8, #T_8c9f4_row1_col6 {
#   background-color: #443983;
#   color: #f1f1f1;
# }
# #T_8c9f4_row1_col0 {
#   background-color: #424186;
#   color: #f1f1f1;
# }
# #T_8c9f4_row1_col2, #T_8c9f4_row6_col8 {
#   background-color: #482979;
#   color: #f1f1f1;
# }
# #T_8c9f4_row1_col3 {
#   background-color: #453581;
#   color: #f1f1f1;
# }
# #T_8c9f4_row1_col4 {
#   background-color: #2c728e;
#   color: #f1f1f1;
# }
# #T_8c9f4_row1_col5, #T_8c9f4_row3_col6 {
#   background-color: #404688;
#   color: #f1f1f1;
# }
# #T_8c9f4_row1_col7 {
#   background-color: #30698e;
#   color: #f1f1f1;
# }
# #T_8c9f4_row1_col8 {
#   background-color: #277f8e;
#   color: #f1f1f1;
# }
# #T_8c9f4_row2_col0, #T_8c9f4_row7_col2 {
#   background-color: #404588;
#   color: #f1f1f1;
# }
# #T_8c9f4_row2_col1 {
#   background-color: #482475;
#   color: #f1f1f1;
# }
# #T_8c9f4_row2_col3 {
#   background-color: #365c8d;
#   color: #f1f1f1;
# }
# #T_8c9f4_row2_col4 {
#   background-color: #463480;
#   color: #f1f1f1;
# }
# #T_8c9f4_row2_col5, #T_8c9f4_row6_col3 {
#   background-color: #39568c;
#   color: #f1f1f1;
# }
# #T_8c9f4_row2_col6 {
#   background-color: #481b6d;
#   color: #f1f1f1;
# }
# #T_8c9f4_row2_col7 {
#   background-color: #32648e;
#   color: #f1f1f1;
# }
# #T_8c9f4_row3_col2, #T_8c9f4_row5_col1 {
#   background-color: #443b84;
#   color: #f1f1f1;
# }
# #T_8c9f4_row3_col4 {
#   background-color: #238a8d;
#   color: #f1f1f1;
# }
# #T_8c9f4_row3_col5 {
#   background-color: #2c738e;
#   color: #f1f1f1;
# }
# #T_8c9f4_row3_col8 {
#   background-color: #450457;
#   color: #f1f1f1;
# }
# #T_8c9f4_row4_col0 {
#   background-color: #440256;
#   color: #f1f1f1;
# }
# #T_8c9f4_row4_col1 {
#   background-color: #365d8d;
#   color: #f1f1f1;
# }
# #T_8c9f4_row4_col2 {
#   background-color: #471365;
#   color: #f1f1f1;
# }
# #T_8c9f4_row4_col3 {
#   background-color: #218f8d;
#   color: #f1f1f1;
# }
# #T_8c9f4_row4_col5 {
#   background-color: #433e85;
#   color: #f1f1f1;
# }
# #T_8c9f4_row4_col6 {
#   background-color: #3f4788;
#   color: #f1f1f1;
# }
# #T_8c9f4_row4_col7, #T_8c9f4_row7_col6 {
#   background-color: #48186a;
#   color: #f1f1f1;
# }
# #T_8c9f4_row4_col8 {
#   background-color: #481a6c;
#   color: #f1f1f1;
# }
# #T_8c9f4_row5_col0 {
#   background-color: #482173;
#   color: #f1f1f1;
# }
# #T_8c9f4_row5_col2, #T_8c9f4_row5_col4 {
#   background-color: #3b528b;
#   color: #f1f1f1;
# }
# #T_8c9f4_row5_col3 {
#   background-color: #25858e;
#   color: #f1f1f1;
# }
# #T_8c9f4_row5_col6, #T_8c9f4_row8_col3 {
#   background-color: #443a83;
#   color: #f1f1f1;
# }
# #T_8c9f4_row5_col7 {
#   background-color: #472f7d;
#   color: #f1f1f1;
# }
# #T_8c9f4_row5_col8 {
#   background-color: #3c508b;
#   color: #f1f1f1;
# }
# #T_8c9f4_row6_col0 {
#   background-color: #471164;
#   color: #f1f1f1;
# }
# #T_8c9f4_row6_col1 {
#   background-color: #481f70;
#   color: #f1f1f1;
# }
# #T_8c9f4_row6_col4 {
#   background-color: #3c4f8a;
#   color: #f1f1f1;
# }
# #T_8c9f4_row6_col5 {
#   background-color: #472d7b;
#   color: #f1f1f1;
# }
# #T_8c9f4_row6_col7 {
#   background-color: #472e7c;
#   color: #f1f1f1;
# }
# #T_8c9f4_row7_col0 {
#   background-color: #20a386;
#   color: #f1f1f1;
# }
# #T_8c9f4_row7_col1 {
#   background-color: #3f4889;
#   color: #f1f1f1;
# }
# #T_8c9f4_row7_col5 {
#   background-color: #46075a;
#   color: #f1f1f1;
# }
# #T_8c9f4_row7_col8 {
#   background-color: #423f85;
#   color: #f1f1f1;
# }
# #T_8c9f4_row8_col0, #T_8c9f4_row8_col5 {
#   background-color: #375a8c;
#   color: #f1f1f1;
# }
# #T_8c9f4_row8_col1 {
#   background-color: #26818e;
#   color: #f1f1f1;
# }
# #T_8c9f4_row8_col2 {
#   background-color: #460a5d;
#   color: #f1f1f1;
# }
# #T_8c9f4_row8_col4 {
#   background-color: #424086;
#   color: #f1f1f1;
# }
# #T_8c9f4_row8_col6 {
#   background-color: #414487;
#   color: #f1f1f1;
# }
# #T_8c9f4_row8_col7 {
#   background-color: #33638d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8c9f4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8c9f4_level0_col0" class="col_heading level0 col0" >Pregnancies</th>
#       <th id="T_8c9f4_level0_col1" class="col_heading level0 col1" >Glucose</th>
#       <th id="T_8c9f4_level0_col2" class="col_heading level0 col2" >BloodPressure</th>
#       <th id="T_8c9f4_level0_col3" class="col_heading level0 col3" >SkinThickness</th>
#       <th id="T_8c9f4_level0_col4" class="col_heading level0 col4" >Insulin</th>
#       <th id="T_8c9f4_level0_col5" class="col_heading level0 col5" >BMI</th>
#       <th id="T_8c9f4_level0_col6" class="col_heading level0 col6" >DiabetesPedigreeFunction</th>
#       <th id="T_8c9f4_level0_col7" class="col_heading level0 col7" >Age</th>
#       <th id="T_8c9f4_level0_col8" class="col_heading level0 col8" >Outcome</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8c9f4_level0_row0" class="row_heading level0 row0" >Pregnancies</th>
#       <td id="T_8c9f4_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_8c9f4_row0_col1" class="data row0 col1" >0.129459</td>
#       <td id="T_8c9f4_row0_col2" class="data row0 col2" >0.141282</td>
#       <td id="T_8c9f4_row0_col3" class="data row0 col3" >-0.081672</td>
#       <td id="T_8c9f4_row0_col4" class="data row0 col4" >-0.073535</td>
#       <td id="T_8c9f4_row0_col5" class="data row0 col5" >0.017683</td>
#       <td id="T_8c9f4_row0_col6" class="data row0 col6" >-0.033523</td>
#       <td id="T_8c9f4_row0_col7" class="data row0 col7" >0.544341</td>
#       <td id="T_8c9f4_row0_col8" class="data row0 col8" >0.221898</td>
#     </tr>
#     <tr>
#       <th id="T_8c9f4_level0_row1" class="row_heading level0 row1" >Glucose</th>
#       <td id="T_8c9f4_row1_col0" class="data row1 col0" >0.129459</td>
#       <td id="T_8c9f4_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_8c9f4_row1_col2" class="data row1 col2" >0.152590</td>
#       <td id="T_8c9f4_row1_col3" class="data row1 col3" >0.057328</td>
#       <td id="T_8c9f4_row1_col4" class="data row1 col4" >0.331357</td>
#       <td id="T_8c9f4_row1_col5" class="data row1 col5" >0.221071</td>
#       <td id="T_8c9f4_row1_col6" class="data row1 col6" >0.137337</td>
#       <td id="T_8c9f4_row1_col7" class="data row1 col7" >0.263514</td>
#       <td id="T_8c9f4_row1_col8" class="data row1 col8" >0.466581</td>
#     </tr>
#     <tr>
#       <th id="T_8c9f4_level0_row2" class="row_heading level0 row2" >BloodPressure</th>
#       <td id="T_8c9f4_row2_col0" class="data row2 col0" >0.141282</td>
#       <td id="T_8c9f4_row2_col1" class="data row2 col1" >0.152590</td>
#       <td id="T_8c9f4_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_8c9f4_row2_col3" class="data row2 col3" >0.207371</td>
#       <td id="T_8c9f4_row2_col4" class="data row2 col4" >0.088933</td>
#       <td id="T_8c9f4_row2_col5" class="data row2 col5" >0.281805</td>
#       <td id="T_8c9f4_row2_col6" class="data row2 col6" >0.041265</td>
#       <td id="T_8c9f4_row2_col7" class="data row2 col7" >0.239528</td>
#       <td id="T_8c9f4_row2_col8" class="data row2 col8" >0.065068</td>
#     </tr>
#     <tr>
#       <th id="T_8c9f4_level0_row3" class="row_heading level0 row3" >SkinThickness</th>
#       <td id="T_8c9f4_row3_col0" class="data row3 col0" >-0.081672</td>
#       <td id="T_8c9f4_row3_col1" class="data row3 col1" >0.057328</td>
#       <td id="T_8c9f4_row3_col2" class="data row3 col2" >0.207371</td>
#       <td id="T_8c9f4_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_8c9f4_row3_col4" class="data row3 col4" >0.436783</td>
#       <td id="T_8c9f4_row3_col5" class="data row3 col5" >0.392573</td>
#       <td id="T_8c9f4_row

# %%
plt.figure(figsize=PLOT_MEDIUM)
sns.heatmap(data_correlation, annot=True, fmt='.2f')
plt.show()

# %%
plt.figure(figsize=PLOT_MEDIUM)
data.Outcome.value_counts().plot(kind='bar')
plt.show()

# %%
# get X and y vars
y = data['Outcome']
X = data.drop('Outcome', axis=1)

# %%
# Balance vars
sm = KMeansSMOTE(kmeans_estimator=MiniBatchKMeans(n_init=1, random_state=0), random_state=42)
X, y = sm.fit_resample(X, y)

# Check
y.value_counts()
# Out:
# Outcome
# 1    502
# 0    500
# Name: count, dtype: int64

# %%
# Normalize
y /= np.max(y)
X /= np.max(X, axis=0)

# %%
# Get train and test subsets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0 ,test_size=0.2)

print('X_train: ', X_train.shape)
print('X_test: ', X_test.shape)
print('y_train: ', y_train.shape)
print('y_test: ', y_test.shape)
# Out:
# X_train:  (801, 8)
# X_test:  (201, 8)
# y_train:  (801,)
# y_test:  (201,)

# %%
import mlflow
import mlflow.keras
import mlflow.sklearn
from datetime import datetime

# %%
# Informando dataset no mlflow
mlflow_dataset = mlflow.data.from_pandas(data, \
                                         source="datasets_diabetes.csv", 
                                         name="Diabetes Dataset")

# %%
RELU = 'relu'
SIGMOID = 'sigmoid'

n_seeds = 2
n_neurons = 256
batch_size = 8
epochs = 30
random_state = 42

mlflow.set_experiment("Exercicio_Keras_Grupo_Ivandro_Pablo")

with mlflow.start_run():
    mlflow.set_tag("mlflow.runName", "Keras: " + str(datetime.now()))
    mlflow.log_input(mlflow_dataset)
    
    mlflow.log_param("n_seeds", n_seeds)
    mlflow.log_param("n_neurons", n_neurons)
    mlflow.log_param("batch_size", batch_size)
    mlflow.log_param("epochs", epochs)
    mlflow.log_param("random_state", random_state)

    ## START MODELO SEQUENCIAL

    tf.random.set_seed(n_seeds)
    
    es = EarlyStopping(monitor = 'val_loss', min_delta = 0.001, patience = 10, verbose = 1, mode = 'auto')

    new_train_x, x_val, new_train_y, y_val = train_test_split(X_train, y_train, 
                                                              test_size = 0.2, 
                                                              random_state = random_state)

    NN_model = Sequential([
        Dense(n_neurons, activation = RELU, input_shape=(X_train.shape[1],)),
        Dense(n_neurons, activation = RELU),
        Dense(n_neurons, activation = RELU),
        Dense(1, activation = SIGMOID)
    ])
    
    NN_model.compile(
        loss='binary_crossentropy',
        optimizer='adamax',
        metrics=['accuracy']
    )
    
    
    train_history = NN_model.fit(new_train_x, new_train_y,
        validation_data=(x_val, y_val),
        batch_size = batch_size,
        shuffle=True,
        epochs = epochs,
        verbose = 1,
        callbacks = [es]
    )

    ## END NOVO MODELO
        
    # modelo
    mlflow.keras.log_model(NN_model, "Keras_Model")
    
    pred_es = NN_model.predict(X_test)
    y_pred = [np.round(i[0]) for i in pred_es]
    results = NN_model.evaluate(X_test, y_test)
    accuracy = accuracy_score(y_test, y_pred)
    cm = confusion_matrix(y_test, y_pred)

    print('Acurácia:' + str(accuracy))
    mlflow.log_metric("accuracy", accuracy)
    
    print(classification_report(y_test, y_pred))

    cm = confusion_matrix(y_test, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["No", "Yes"])
    disp.plot()
    
    plt.savefig("confusion_diabetes.png")
    plt.close()

    mlflow.log_artifact("confusion_diabetes.png")

mlflow.end_run()
# Out:
# Epoch 1/30
# 80/80 [==============================] - 2s 7ms/step - loss: 0.6594 - accuracy: 0.6156 - val_loss: 0.6258 - val_accuracy: 0.7267
# Epoch 2/30
# 80/80 [==============================] - 0s 4ms/step - loss: 0.5948 - accuracy: 0.7141 - val_loss: 0.5610 - val_accuracy: 0.7143
# Epoch 3/30
# 80/80 [==============================] - 0s 5ms/step - loss: 0.5645 - accuracy: 0.7297 - val_loss: 0.5354 - val_accuracy: 0.7391
# Epoch 4/30
# 80/80 [==============================] - 0s 4ms/step - loss: 0.5355 - accuracy: 0.7547 - val_loss: 0.5238 - val_accuracy: 0.7702
# Epoch 5/30
# 80/80 [==============================] - 0s 4ms/step - loss: 0.5226 - accuracy: 0.7656 - val_loss: 0.4961 - val_accuracy: 0.7702
# Epoch 6/30
# 80/80 [==============================] - 0s 4ms/step - loss: 0.4994 - accuracy: 0.7812 - val_loss: 0.4942 - val_accuracy: 0.7578
# Epoch 7/30
# 80/80 [==============================] - 0s 5ms/step - loss: 0.4825 - accuracy: 0.7766 - val_loss: 0.4572 - val_accuracy: 0.8012
# Epoch 8/30
# 80/80 [==============================] - 0s 5ms/step - loss: 0.4700 - accuracy: 0.7828 - val_loss: 0.4363 - val_accuracy: 0.8323
# Epoch 9/30
# 80/80 [==============================] - 0s 4ms/step - loss: 0.4545 - accuracy: 0.7984 - val_loss: 0.4276 - val_accuracy: 0.8199
# Epoch 10/30
# 80/80 [==============================] - 0s 5ms/step - loss: 0.4550 - accuracy: 0.7984 - val_loss: 0.5245 - val_accuracy: 0.7888
# Epoch 11/30
# 80/80 [==============================] - 0s 5ms/step - loss: 0.4555 - accuracy: 0.7922 - val_loss: 0.4956 - val_accuracy: 0.7702
# Epoch 12/30
# 80/80 [==============================] - 0s 5ms/step - loss: 0.4574 - accuracy: 0.7906 - val_loss: 0.4325 - val_accuracy: 0.8199
# Epoch 13/30
# 80/80 [==============================] - 1s 7ms/step - loss: 0.4450 - accuracy: 0.8000 - val_loss: 0.4521 - val_accuracy: 0.8012
# Epoch 14/30
# 80/80 [==============================] - 1s 7ms/step - loss: 0.4358 - accuracy: 0.8016 - val_loss: 0.4331 - val_accuracy: 0.8199
# Epoch 15/30
# 80/80 [==============================] - 0s 5ms/step - loss: 0.4246 - accuracy: 0.8000 - val_loss: 0.4276 - val_accuracy: 0.8261
# Epoch 16/30
# 80/80 [==============================] - 0s 5ms/step - loss: 0.4325 - accuracy: 0.8094 - val_loss: 0.4094 - val_accuracy: 0.8199
# Epoch 17/30
# 80/80 [==============================] - 0s 5ms/step - loss: 0.4283 - accuracy: 0.8125 - val_loss: 0.4076 - val_accuracy: 0.8199
# Epoch 18/30
# 80/80 [==============================] - 0s 5ms/step - loss: 0.4156 - accuracy: 0.8125 - val_loss: 0.4379 - val_accuracy: 0.8075
# Epoch 19/30
# 80/80 [==============================] - 0s 6ms/step - loss: 0.4105 - accuracy: 0.8188 - val_loss: 0.4076 - val_accuracy: 0.8137
# Epoch 20/30
# 80/80 [==============================] - 0s 5ms/step - loss: 0.4170 - accuracy: 0.8219 - val_loss: 0.4503 - val_accuracy: 0.8137
# Epoch 21/30
# 80/80 [==============================] - 0s 5ms/step - loss: 0.4329 - accuracy: 0.8016 - val_loss: 0.4189 - val_accuracy: 0.8075
# Epoch 22/30
# 80/80 [==============================] - 0s 6ms/step - loss: 0.4111 - accuracy: 0.8219 - val_loss: 0.4111 - val_accuracy: 0.8075
# Epoch 23/30
# 80/80 [==============================] - 0s 5ms/step - loss: 0.4062 - accuracy: 0.8234 - val_loss: 0.4249 - val_accuracy: 0.8075
# Epoch 24/30
# 80/80 [==============================] - 0s 6ms/step - loss: 0.3995 - accuracy: 0.8359 - val_loss: 0.5454 - val_accuracy: 0.7702
# Epoch 25/30
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3985 - accuracy: 0.8234 - val_loss: 0.4208 - val_accuracy: 0.8137
# Epoch 26/30
# 80/80 [==============================] - 0s 5ms/step - loss: 0.4174 - accuracy: 0.8141 - val_loss: 0.4167 - val_accuracy: 0.8199
# Epoch 27/30
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3878 - accuracy: 0.8313 - val_loss: 0.4337 - val_accuracy: 0.8137
# Epoch 27: early stopping
# 2023/11/09 19:29:56 WARNING mlflow.tensorflow: You are saving a TensorFlow Core model or Keras model without a signature. Inference with mlflow.pyfunc.spark_udf() will not work unless the model's pyfunc representation accepts pandas DataFrames as inference inputs.
# INFO:tensorflow:Assets written to: C:\Users\PSEBAS~1\AppData\Local\Temp\tmp69p_f8sk\model\data\model\assets
# INFO:tensorflow:Assets written to: C:\Users\PSEBAS~1\AppData\Local\Temp\tmp69p_f8sk\model\data\model\assets
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3038 - accuracy: 0.8856
# Acurácia:0.8855721393034826
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.95      0.89       100
#          1.0       0.94      0.82      0.88       101
#
#     accuracy                           0.89       201
#    macro avg       0.89      0.89      0.89       201
# weighted avg       0.89      0.89      0.89       201

# %%
mlflow.set_experiment("Exercicio_Keras_Grupo_Ivandro_Pablo")

n_estimators = 100


with mlflow.start_run():
    mlflow.set_tag("mlflow.runName", "Random Forest: " + str(datetime.now()))
    mlflow.log_input(mlflow_dataset)
    
    mlflow.log_param("n_estimators", n_estimators)
    mlflow.log_param("random_state", random_state)


    model_rf = RandomForestClassifier(n_estimators = n_estimators, \
                                      random_state = random_state)
    
    model_rf.fit(X_train, y_train)
    y_pred = model_rf.predict(X_test)
    
    # modelo
    
    mlflow.sklearn.log_model(model_rf, "Random_Forest")
    
    accuracy = round(accuracy_score(y_test, y_pred), 2)
    print('Acurácia:' + str(accuracy))
    
    mlflow.log_metric("accuracy", accuracy)
    print(classification_report(y_test, y_pred))

    cm = confusion_matrix(y_test, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["No", "Yes"])
    disp.plot()

    plt.savefig("confusion_rf_diabetes.png")
    plt.close()

    mlflow.log_artifact("confusion_rf_diabetes.png")

mlflow.end_run()
# Out:
# Acurácia:0.89
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.89      0.89       100
#          1.0       0.89      0.89      0.89       101
#
#     accuracy                           0.89       201
#    macro avg       0.89      0.89      0.89       201
# weighted avg       0.89      0.89      0.89       201
